# %%
pip install tweepy

# %%
import tweepy
import pandas as pd
import csv

# %%
consumer_key = 'Nj7pYtoSKQhWdxOFhjO3VBGNB'
consumer_secret = 'JKNZX2yILqreg3vLadBWXRvB01nFrMZFRfqy4XowoJjjax0Ha2'
access_token = '1130490153460412416-Sh7f5IKGBxIgpsxG23u9Pg6Z3Oqr1j'
access_token_secret = 'gYxPDBdrcbbiPawmPQ9CkRCY1QNEQqA1LT2W76nIEqbhz'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
pd.options.display.max_colwidth = 240
text = []
api = tweepy.API(auth,wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
search_words = '#ตรวจหวย'
new_search = search_words + " -filter:retweets"
#new_search = search_words
search = tweepy.Cursor(api.search, q=new_search, lang="th", tweet_mode="extended").items(100)

text = [item.full_text for item in search]
#print(type(text[0]))
#print(type('i'))
df = pd.DataFrame(text)
df.duplicated()
df.drop_duplicates()
df.head(n= 100)
# Out:
#                                                                                                                                                                                                                                                   0
# 0                                                                                                                                   มีใครสนใจทักมาได้สอบถาม มีหลายรุ่น #ไอ้ไข่ #ไอ้ไข่เด็กวัดเจดีย์ #หวยเด็ดงวดนี้ #ตรวจหวย https://t.co/UIWnfeq07V
# 1   วิธีการสมัครสมาชิกของ เว็บ #Fo1bet \nท่านไหนสนใจลองเข้าไปชมได้เลย\nบอกละเอียดทุกขั้นตอน\n\nhttps://t.co/PzIfTjUPpQ\n\n#fo1bet #แทงหวย #หวยออนไลน์ #หวยรัฐบาล #หวยยี่กี #หวยฮานอย #หวยลาว #หวยหุ้นไทย #หวยเด็ดงวดนี้ #หวยดัง #เลขดัง #เลขเด็ด...
# 2   🌻🌻🌻แจกแมวกวักทอง1ชิ้น🌻🌻🌻\n\nกติกา รี+ฟลว.ทวิต❗️\n\nพร้อมกดติดตาม ig : poppy_rjk แล้วแปะรูปมาได้เลยน้า\n\nสุ่ม23.20น.แล้วจะแท็กหาค่า \n(ตอนนี้คนเล่นไม่เยอะรีบเล่นน้า โอกาสได้เยอะมั่กๆงับ)\n#ดูดวง #ดูดวงความรัก #ดูดวงการเรียน #ดูดวงฟรี #แ...
# ...

# %%
trends = api.trends_place(23424960)[0]['trends']
top_10 = trends[:10]
print(trends)

for trend in top_10:
  print(trend['name'])
# Out:
# [{'name': '#แบนแทกุกไลน์', 'url': 'http://twitter.com/search?q=%23%E0%B9%81%E0%B8%9A%E0%B8%99%E0%B9%81%E0%B8%97%E0%B8%81%E0%B8%B8%E0%B8%81%E0%B9%84%E0%B8%A5%E0%B8%99%E0%B9%8C', 'promoted_content': None, 'query': '%23%E0%B9%81%E0%B8%9A%E0%B8%99%E0%B9%81%E0%B8%97%E0%B8%81%E0%B8%B8%E0%B8%81%E0%B9%84%E0%B8%A5%E0%B8%99%E0%B9%8C', 'tweet_volume': 252786}, {'name': '#whatshappeninginthailand', 'url': 'http://twitter.com/search?q=%23whatshappeninginthailand', 'promoted_content': None, 'query': '%23whatshappeninginthailand', 'tweet_volume': 1153130}, {'name': '#แบนscb', 'url': 'http://twitter.com/search?q=%23%E0%B9%81%E0%B8%9A%E0%B8%99scb', 'promoted_content': None, 'query': '%23%E0%B9%81%E0%B8%9A%E0%B8%99scb', 'tweet_volume': 98892}, {'name': 'Good Mewning', 'url': 'http://twitter.com/search?q=%22Good+Mewning%22', 'promoted_content': None, 'query': '%22Good+Mewning%22', 'tweet_volume': 17941}, {'name': '#missgrandthailand2020', 'url': 'http://twitter.com/search?q=%23missgrandthailand2020', '
# ...

# %%
df.shape
# Out:
# (1949, 1)

# %%
for item in search:
  print(item)

# %%
with open("dataset5.csv", mode='w', newline='') as f:
  thewriter = csv.writer(f)
  thewriter.writerow(["text_id","sentiment","text","date","tweet_id"])
pd.options.display.max_colwidth = 240
text = []
api = tweepy.API(auth,wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
search_words = '#ฉลาดเกมส์โกงep7'
new_search = search_words + " -filter:retweets"
with open("dataset5.csv", mode='a', newline='') as f:
  id = 0
  thewriter = csv.writer(f)
  for tweet in tweepy.Cursor(api.search, q=new_search, lang="th", tweet_mode="extended", until='2020-08-30' ).items(10000):
    id+=1
    text = tweet.full_text
    text = text.replace('\n', '')
    thewriter.writerow([id,'',text,tweet.created_at,tweet.id])
# Out:
# Rate limit reached. Sleeping for: 868

# %%
from tweepy.streaming import StreamListener
from tweepy import Stream
import datetime
import csv

# %%
class StdOutListener(StreamListener):
    def on_status(self, status):
        
        # Filtering English language tweets from users with more than 500 followers
        if (status.lang == "th"):
            # Creating this formatting so when exported to csv the tweet stays on one line
            
            tweet_text = "'" + status.text.replace('\n', ' ') + "'"
            if hasattr(status, 'retweeted_status') is False:
              id = 1
              csvw.writerow([id,
                             '',
                             tweet_text,
                             status.id,
                            
                            # created_at is a datetime object, converting to just grab the month/day/year
                            status.created_at])
              print("added")
              
            return True

    def on_error(self, status_code):
        if status_code == 420:
            # returning False in on_error disconnects the stream
            return False

# %%
l = StdOutListener()
#auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
stream = Stream(auth, l)

    # Filter based on listed items
csvw = csv.writer(open("ฉลาดเกมส์โกงตอนจบ.csv", "a"))
csvw.writerow(['text_id','sentiment','text','tweet_id','time',])
print("Start streaming")
stream.filter(track=['#ฉลาดเกมส์โกงตอนจบ'])
# Out:
# Start streaming
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# ...

# %%
from google.colab import files
files.download('ฉลาดเกมส์โกงep11.csv')
